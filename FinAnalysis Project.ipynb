# %%
from pandas_datareader import data, wb
import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %%
start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2020, 1, 1)

# %%
BAC = data.DataReader('BAC', 'yahoo', start, end)
C = data.DataReader('C', 'yahoo', start, end)
GS = data.DataReader('GS', 'yahoo', start, end)
JPM = data.DataReader('JPM', 'yahoo', start, end)
MS = data.DataReader('MS', 'yahoo', start, end)
WFC = data.DataReader('WFC', 'yahoo', start, end)

# %%
C
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2018-01-02  75.180000  74.019997  75.089996  74.360001  15819800.0  68.836151
# 2018-01-03  74.739998  73.970001  74.349998  74.589996  14657900.0  69.049072
# 2018-01-04  76.110001  74.660004  75.010002  75.510002  16864900.0  69.900734
# 2018-01-05  75.769997  74.959999  75.709999  75.410004  15300500.0  69.808159
# 2018-01-08  75.239998  74.330002  75.169998  74.529999  14215700.0  68.993530
# ...               ...        ...        ...        ...         ...        ...
# 2019-12-24  78.940002  78.459999  78.699997  78.589996   4576200.0  76.477905
# 2019-12-26  79.839996  78.650002  78.750000  79.830002  11992800.0  77.684586
# 2019-12-27  80.180000  79.580002  80.000000  79.669998  10867900.0  77.528885
# 2019-12-30  80.419998  79.339996  80.150002  79.510002  10084900.0  77.373184
# 2019-12-31  79.940002  79.099998  79.320000  79.889999   8031200.0  77.742973
#
# [503 rows x 6 columns]

# %%
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
tickers
# Out:
# ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %%
bank_stocks = pd.concat([BAC, C, GS, JPM, MS, WFC], axis = 1, keys = tickers)

# %%
bank_stocks
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2018-01-02  29.900000  29.610001  29.750000  29.900000  57121600.0  28.131578
# 2018-01-03  29.940001  29.690001  29.900000  29.799999  57865700.0  28.037491
# 2018-01-04  30.440001  29.879999  29.969999  30.190001  76512500.0  28.404425
# 2018-01-05  30.420000  30.049999  30.370001  30.330000  56445200.0  28.536144
# 2018-01-08  30.270000  30.049999  30.230000  30.120001  42914800.0  28.338566
# ...               ...        ...        ...        ...         ...        ...
# 2019-12-24  35.279999  35.119999  35.189999  35.220001  13805400.0  34.513897
# 2019-12-26  35.560001  35.290001  35.320000  35.520000  26992100.0  34.807880
# 2019-12-27  35.720001  35.259998  35.700001  35.349998  28111300.0  34.641285
# 2019-12-30  35.650002  35.090000  35.570000  35.150002  30705100.0  34.445301
# ...

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %%
bank_stocks
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2018-01-02   29.900000  29.610001  29.750000  29.900000  57121600.0
# 2018-01-03   29.940001  29.690001  29.900000  29.799999  57865700.0
# 2018-01-04   30.440001  29.879999  29.969999  30.190001  76512500.0
# 2018-01-05   30.420000  30.049999  30.370001  30.330000  56445200.0
# 2018-01-08   30.270000  30.049999  30.230000  30.120001  42914800.0
# ...                ...        ...        ...        ...         ...
# 2019-12-24   35.279999  35.119999  35.189999  35.220001  13805400.0
# 2019-12-26   35.560001  35.290001  35.320000  35.520000  26992100.0
# 2019-12-27   35.720001  35.259998  35.700001  35.349998  28111300.0
# 2019-12-30   35.650002  35.090000  35.570000  35.150002  30705100.0
# 2019-12-31   35.259998  34.970001  35.029999  35.220001  29630100.0
#
# Bank Ticker                     C                                   ...  \
# ...

# %%
for tick in tickers: 
    print(tick, bank_stocks[tick]['Close'].max())
# Out:
# BAC 35.52000045776367
# C 80.08000183105469
# GS 273.3800048828125
# JPM 139.39999389648438
# MS 58.90999984741211
# WFC 65.93000030517578

# %%
bank_stocks.xs(key = 'Close', axis = 1, level = 'Stock Info').max()
# Out:
# Bank Ticker
# BAC     35.520000
# C       80.080002
# GS     273.380005
# JPM    139.399994
# MS      58.910000
# WFC     65.930000
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in tickers: 
    returns[tick +'Return'] = bank_stocks[tick]['Close'].pct_change()

# %%
returns.head()
# Out:
#             BACReturn   CReturn  GSReturn  JPMReturn  MSReturn  WFCReturn
# Date
# 2018-01-02        NaN       NaN       NaN        NaN       NaN        NaN
# 2018-01-03  -0.003344  0.003093 -0.009309   0.001019  0.002683   0.007694
# 2018-01-04   0.013087  0.012334  0.013976   0.009069  0.015288   0.012508
# 2018-01-05   0.004637 -0.001324 -0.005101  -0.006420 -0.000376   0.006738
# 2018-01-08  -0.006924 -0.011670 -0.014519   0.001477 -0.004142  -0.011315

# %%
import seaborn as sns
sns.pairplot(returns[1:])

# %%
returns.idxmin()
# Out:
# BACReturn   2018-12-04
# CReturn     2019-08-14
# GSReturn    2018-11-12
# JPMReturn   2018-02-05
# MSReturn    2018-05-29
# WFCReturn   2018-02-05
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BACReturn   2019-01-16
# CReturn     2019-06-04
# GSReturn    2019-01-16
# JPMReturn   2019-04-12
# MSReturn    2018-12-26
# WFCReturn   2018-12-26
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BACReturn    0.015126
# CReturn      0.015305
# GSReturn     0.015612
# JPMReturn    0.012935
# MSReturn     0.016022
# WFCReturn    0.013698
# dtype: float64

# %%
returns.loc['2019-01-01':'2019-12-31'].std()
# Out:
# BACReturn    0.014566
# CReturn      0.015354
# GSReturn     0.014890
# JPMReturn    0.011869
# MSReturn     0.014701
# WFCReturn    0.012450
# dtype: float64

# %%
sns.distplot(returns.loc['2019-01-01':'2019-12-31']['MSReturn'], bins = 50)

# %%
sns.distplot(returns.loc['2019-01-01':'2019-12-31']['CReturn'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for tick in tickers: 
    bank_stocks[tick]['Close'].plot(figsize = (10, 2), label = tick)
plt.legend(bbox_to_anchor = (1.2, 1), borderaxespad = 0)

# %%
bank_stocks.xs(key = 'Close', axis = 1, level = 'Stock Info').plot(figsize = (10,2))
plt.legend(bbox_to_anchor = (1.2, 1), borderaxespad = 0)

# %%
 bank_stocks.xs(key = 'Close', axis = 1, level = 'Stock Info').iplot()
# Out:
# <div>                            <div id="59681bc8-4514-474b-8c67-160b46bc9b3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
plt.figure(figsize = (10,2))
C['Close'].loc['2018-01-01':'2019-01-01'].rolling(window = 30).mean().plot(label = '30 day AVG')
C['Close'].loc['2018-01-01':'2019-01-01'].plot(label = 'C Close')
plt.legend()

# %%
bs = bank_stocks.xs(key = 'Close', axis= 1, level = 'Stock Info').corr()
sns.heatmap(data = bs)

# %%
sns.clustermap(data = bs, annot = True)

# %%
bs.iplot(kind = 'heatmap', colorscale = 'rdylbu')
# Out:
# <div>                            <div id="aaf2fa69-25e2-47dd-873b-6352e7ef1efb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
import plotly.graph_objects as go

# %%
c19 = C[['Open', 'High', 'Low', 'Close']].loc['2019-01-01':'2019-12-31']
c19.iplot(kind= 'candle')
# Out:
# <div>                            <div id="fe3f2c5f-0459-4d5a-b8c9-6efd33668006" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
ms19 = MS[['Close']].loc['2019-01-01':'2019-12-31']
ms19.ta_plot(study = 'sma', periods = [13,21,55])
# Out:
# <div>                            <div id="0610f402-cf68-45d7-926c-ab538d5adee2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
JPM['Close'].loc['2018-01-01':'2018-12-31'].ta_plot(study = 'boll')
# Out:
# <div>                            <div id="637ed44d-0623-4fe4-9abd-264e9717fdff" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
